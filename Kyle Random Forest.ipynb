# %%
# Import the modules
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# ---

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %% [markdown]
# ### Step 1: Read the `lending_data.csv` data from the `Resources` folder into a Pandas DataFrame.

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
df_analysis = pd.read_csv("Resources/data_cleaned.csv", index_col=0)

# Review the DataFrame
df_analysis
# Out:
#                    pin  Property Class  Neighborhood Code  Land Square Feet  \
# 12      25153030260000             202                210              4158
# 26      20273010160000             211                111              5313
# 27      20341050210000             211                111              4500
# 63      20223010160000             203                 30              3300
# 85      25011050180000             202                130              3643
# ...                ...             ...                ...               ...
# 212271  17301160040000             211                141              2400
# 212301  17063060040000             211                 52              2600
# 212389  14311240200000             205                170              3600
# 212394  16162141890000             295                 80              1017
# 212400  16121020080000             211                101              3175
#
#         Town Code  Type of Residence  Apartments  Rooms  Bedrooms  Basement  \
# 12             70                1.0           0      4         2         4
# 26             70                2.0           2      7         4         1
# 27             70                2.0           2      7         4         1
# 63             70                1.0           0      5         3         1
# 85             70                1.0           0      5         3         1
# ...           ...                ...         ...    ...       ...       ...
# 212271         77                1.0           2      8         4         1
# 212301         77                2.0           2     10         4         1
# 212389         77                2.0           0      9         4         1
# 212394         77                2.0           0      4         2         2
# 212400         77                2.0           2      7         4         1
#
#         ...  num_foreclosure_in_half_mile_past_5_years  \
# 12      ...                                        203
# 26      ...                                        167
# 27      ...                                        206
# 63      ...                                         84
# 85      ...                                         79
# ...     ...                                        ...
# 212271  ...                                         29
# 212301  ...                                          9
# 212389  ...                                         11
# 212394  ...                                        149
# 212400  ...                                         69
#
#         num_foreclosure_per_1000_pin_past_5_years  nearest_cta_route_name  \
# 12                                          64.55                Red Line
# 26                                          77.17                Red Line
# 27                                          71.58                Red Line
# 63                                          44.42                Red Line
# 85                                          25.86                Red Line
# ...                                           ...                     ...
# 212271                                      13.46               Pink Line
# 212301                                       2.49               Blue Line
# 212389                                       2.88               Blue Line
# 212394                                      55.10               Blue Line
# 212400                                      32.75              Green Line
#
#         nearest_cta_stop_dist_ft  lake_michigan_dist_ft  \
# 12                   8641.316080           26084.996093
# 26                   2378.981155           15798.238046
# 27                   2483.343963           15881.861019
# 63                   1289.011353           13598.517588
# 85                  11968.230035           11828.693908
# ...                          ...                    ...
# 212271               2309.108308           19530.014594
# 212301               3185.879688           15656.812830
# 212389               1605.104188           15247.702912
# 212394               1952.905851           35789.669486
# 212400               3110.694686           22713.838616
#
#         nearest_metra_stop_dist_ft  nearest_water_dist_ft  \
# 12                     2717.148357            6391.361862
# 26                     7256.411321            3508.897334
# 27                     5154.668579            5247.755218
# 63                     8798.198308            6507.411449
# 85                     5331.604154           10291.059868
# ...                            ...                    ...
# 212271                 3567.946967            2388.975064
# 212301                 4851.155570            4911.124322
# 212389                 5011.158050            3307.171219
# 212394                11523.308495            4453.705514
# 212400                 1663.550266            3842.508220
#
#         nearest_neighbor_1_dist_ft  nearest_neighbor_2_dist_ft  \
# 12                       32.903876                   32.903965
# 26                       29.830339                   32.745589
# 27                       29.998205                   30.015005
# 63                       32.998020                   33.004924
# 85                       30.670624                   60.659963
# ...                            ...                         ...
# 212271                   24.001717                   24.004066
# 212301                   24.970062                   26.459766
# 212389                   30.017950                   33.000013
# 212394                   18.327534                   24.763143
# 212400                   25.004712                   37.491853
#
#         nearest_neighbor_3_dist_ft
# 12                       57.680425
# 26                       56.233720
# 27                       59.785008
# 63                       64.502211
# 85                       90.640905
# ...                            ...
# 212271                   47.991597
# 212301                   50.243183
# 212389                   57.338882
# 212394                   36.645742
# 212400                   50.010324
#
# [11367 rows x 57 columns]

# %%
# Remove columns not necessary for analysis
df_analysis = df_analysis.drop(columns=['Town and Neighborhood', 'pin', 'Property Address', 'Sale Year', 'township_name', 
                                        'property_city', 'property_state'])
# Drop any additional columns here
# df_analysis = df_analysis.drop(columns=[])

df_analysis
# Out:
#         Property Class  Neighborhood Code  Land Square Feet  Town Code  \
# 12                 202                210              4158         70
# 26                 211                111              5313         70
# 27                 211                111              4500         70
# 63                 203                 30              3300         70
# 85                 202                130              3643         70
# ...                ...                ...               ...        ...
# 212271             211                141              2400         77
# 212301             211                 52              2600         77
# 212389             205                170              3600         77
# 212394             295                 80              1017         77
# 212400             211                101              3175         77
#
#         Type of Residence  Apartments  Rooms  Bedrooms  Basement  \
# 12                    1.0           0      4         2         4
# 26                    2.0           2      7         4         1
# 27                    2.0           2      7         4         1
# 63                    1.0           0      5         3         1
# 85                    1.0           0      5         3         1
# ...                   ...         ...    ...       ...       ...
# 212271                1.0           2      8         4         1
# 212301                2.0           2     10         4         1
# 212389                2.0           0      9         4         1
# 212394                2.0           0      4         2         2
# 212400                2.0           2      7         4         1
#
#         Basement Finish  ...  num_foreclosure_in_half_mile_past_5_years  \
# 12                  3.0  ...                                        203
# 26                  3.0  ...                                        167
# 27                  3.0  ...                                        206
# 63                  1.0  ...                                         84
# 85                  3.0  ...                                         79
# ...                 ...  ...                                        ...
# 212271              2.0  ...                                         29
# 212301              3.0  ...                                          9
# 212389              1.0  ...                                         11
# 212394              3.0  ...                                        149
# 212400              1.0  ...                                         69
#
#         num_foreclosure_per_1000_pin_past_5_years  nearest_cta_route_name  \
# 12                                          64.55                Red Line
# 26                                          77.17                Red Line
# 27                                          71.58                Red Line
# 63                                          44.42                Red Line
# 85                                          25.86                Red Line
# ...                                           ...                     ...
# 212271                                      13.46               Pink Line
# 212301                                       2.49               Blue Line
# 212389                                       2.88               Blue Line
# 212394                                      55.10               Blue Line
# 212400                                      32.75              Green Line
#
#         nearest_cta_stop_dist_ft  lake_michigan_dist_ft  \
# 12                   8641.316080           26084.996093
# 26                   2378.981155           15798.238046
# 27                   2483.343963           15881.861019
# 63                   1289.011353           13598.517588
# 85                  11968.230035           11828.693908
# ...                          ...                    ...
# 212271               2309.108308           19530.014594
# 212301               3185.879688           15656.812830
# 212389               1605.104188           15247.702912
# 212394               1952.905851           35789.669486
# 212400               3110.694686           22713.838616
#
#         nearest_metra_stop_dist_ft  nearest_water_dist_ft  \
# 12                     2717.148357            6391.361862
# 26                     7256.411321            3508.897334
# 27                     5154.668579            5247.755218
# 63                     8798.198308            6507.411449
# 85                     5331.604154           10291.059868
# ...                            ...                    ...
# 212271                 3567.946967            2388.975064
# 212301                 4851.155570            4911.124322
# 212389                 5011.158050            3307.171219
# 212394                11523.308495            4453.705514
# 212400                 1663.550266            3842.508220
#
#         nearest_neighbor_1_dist_ft  nearest_neighbor_2_dist_ft  \
# 12                       32.903876                   32.903965
# 26                       29.830339                   32.745589
# 27                       29.998205                   30.015005
# 63                       32.998020                   33.004924
# 85                       30.670624                   60.659963
# ...                            ...                         ...
# 212271                   24.001717                   24.004066
# 212301                   24.970062                   26.459766
# 212389                   30.017950                   33.000013
# 212394                   18.327534                   24.763143
# 212400                   25.004712                   37.491853
#
#         nearest_neighbor_3_dist_ft
# 12                       57.680425
# 26                       56.233720
# 27                       59.785008
# 63                       64.502211
# 85                       90.640905
# ...                            ...
# 212271                   47.991597
# 212301                   50.243183
# 212389                   57.338882
# 212394                   36.645742
# 212400                   50.010324
#
# [11367 rows x 50 columns]

# %%
# Check and remove null values
nan_count = df_analysis.isnull().sum().sum()
print('Number of NaN values:', nan_count)
df_analysis = df_analysis.dropna()
df_analysis
# Out:
# Number of NaN values: 86
#         Property Class  Neighborhood Code  Land Square Feet  Town Code  \
# 12                 202                210              4158         70
# 26                 211                111              5313         70
# 27                 211                111              4500         70
# 63                 203                 30              3300         70
# 85                 202                130              3643         70
# ...                ...                ...               ...        ...
# 212271             211                141              2400         77
# 212301             211                 52              2600         77
# 212389             205                170              3600         77
# 212394             295                 80              1017         77
# 212400             211                101              3175         77
#
#         Type of Residence  Apartments  Rooms  Bedrooms  Basement  \
# 12                    1.0           0      4         2         4
# 26                    2.0           2      7         4         1
# 27                    2.0           2      7         4         1
# 63                    1.0           0      5         3         1
# 85                    1.0           0      5         3         1
# ...                   ...         ...    ...       ...       ...
# 212271                1.0           2      8         4         1
# 212301                2.0           2     10         4         1
# 212389                2.0           0      9         4         1
# 212394                2.0           0      4         2         2
# 212400                2.0           2      7         4         1
#
#         Basement Finish  ...  num_foreclosure_in_half_mile_past_5_years  \
# 12                  3.0  ...                                        203
# 26                  3.0  ...                                        167
# 27                  3.0  ...                                        206
# 63                  1.0  ...                                         84
# 85                  3.0  ...                                         79
# ...                 ...  ...                                        ...
# 212271              2.0  ...                                         29
# 212301              3.0  ...                                          9
# 212389              1.0  ...                                         11
# 212394              3.0  ...                                        149
# 212400              1.0  ...                                         69
#
#         num_foreclosure_per_1000_pin_past_5_years  nearest_cta_route_name  \
# 12                                          64.55                Red Line
# 26                                          77.17                Red Line
# 27                                          71.58                Red Line
# 63                                          44.42                Red Line
# 85                                          25.86                Red Line
# ...                                           ...                     ...
# 212271                                      13.46               Pink Line
# 212301                                       2.49               Blue Line
# 212389                                       2.88               Blue Line
# 212394                                      55.10               Blue Line
# 212400                                      32.75              Green Line
#
#         nearest_cta_stop_dist_ft  lake_michigan_dist_ft  \
# 12                   8641.316080           26084.996093
# 26                   2378.981155           15798.238046
# 27                   2483.343963           15881.861019
# 63                   1289.011353           13598.517588
# 85                  11968.230035           11828.693908
# ...                          ...                    ...
# 212271               2309.108308           19530.014594
# 212301               3185.879688           15656.812830
# 212389               1605.104188           15247.702912
# 212394               1952.905851           35789.669486
# 212400               3110.694686           22713.838616
#
#         nearest_metra_stop_dist_ft  nearest_water_dist_ft  \
# 12                     2717.148357            6391.361862
# 26                     7256.411321            3508.897334
# 27                     5154.668579            5247.755218
# 63                     8798.198308            6507.411449
# 85                     5331.604154           10291.059868
# ...                            ...                    ...
# 212271                 3567.946967            2388.975064
# 212301                 4851.155570            4911.124322
# 212389                 5011.158050            3307.171219
# 212394                11523.308495            4453.705514
# 212400                 1663.550266            3842.508220
#
#         nearest_neighbor_1_dist_ft  nearest_neighbor_2_dist_ft  \
# 12                       32.903876                   32.903965
# 26                       29.830339                   32.745589
# 27                       29.998205                   30.015005
# 63                       32.998020                   33.004924
# 85                       30.670624                   60.659963
# ...                            ...                         ...
# 212271                   24.001717                   24.004066
# 212301                   24.970062                   26.459766
# 212389                   30.017950                   33.000013
# 212394                   18.327534                   24.763143
# 212400                   25.004712                   37.491853
#
#         nearest_neighbor_3_dist_ft
# 12                       57.680425
# 26                       56.233720
# 27                       59.785008
# 63                       64.502211
# 85                       90.640905
# ...                            ...
# 212271                   47.991597
# 212301                   50.243183
# 212389                   57.338882
# 212394                   36.645742
# 212400                   50.010324
#
# [11281 rows x 50 columns]

# %%
# Check property class amounts
df_analysis['Property Class'].value_counts()
# Out:
# Property Class
# 211    3390
# 203    3192
# 202    1413
# 205     887
# 295     500
# 278     463
# 206     294
# 204     244
# 212     239
# 210     213
# 234     198
# 207     190
# 208      39
# 209      19
# Name: count, dtype: int64

# %%
# Get rid of outlier sale prices
df_analysis = df_analysis.drop(df_analysis[df_analysis['Sale Price'] <= 100000].index)
df_analysis = df_analysis.drop(df_analysis[df_analysis['Sale Price'] >= 1000000].index)

# Get rid of unwanted property classes
df_analysis = df_analysis.drop(df_analysis[df_analysis['Property Class'] == 211].index)
df_analysis = df_analysis.drop(df_analysis[df_analysis['Property Class'] == 212].index)
df_analysis = df_analysis.drop(df_analysis[df_analysis['Property Class'] == 210].index)
df_analysis = df_analysis.drop(df_analysis[df_analysis['Property Class'] == 295].index)
df_analysis = df_analysis.drop(df_analysis[df_analysis['Property Class'] == 234].index)

df_analysis
# Out:
#         Property Class  Neighborhood Code  Land Square Feet  Town Code  \
# 85                 202                130              3643         70
# 88                 203                280              5000         70
# 101                205                 83              5625         70
# 104                202                180              5103         70
# 165                203                280              3225         70
# ...                ...                ...               ...        ...
# 211255             203                 40              3125         77
# 211359             203                151              3125         77
# 211518             203                 60              3125         77
# 211999             278                 30              3125         77
# 212208             206                 13              4838         77
#
#         Type of Residence  Apartments  Rooms  Bedrooms  Basement  \
# 85                    1.0           0      5         3         1
# 88                    1.0           0      4         2         1
# 101                   2.0           0      8         4         1
# 104                   1.0           0      4         2         1
# 165                   5.0           0      6         3         1
# ...                   ...         ...    ...       ...       ...
# 211255                5.0           0      7         3         2
# 211359                1.0           0      5         3         1
# 211518                5.0           0      7         4         1
# 211999                2.0           0      7         4         1
# 212208                2.0           0     10         4         1
#
#         Basement Finish  ...  num_foreclosure_in_half_mile_past_5_years  \
# 85                  3.0  ...                                         79
# 88                  1.0  ...                                         75
# 101                 3.0  ...                                        276
# 104                 3.0  ...                                         75
# 165                 3.0  ...                                         35
# ...                 ...  ...                                        ...
# 211255              3.0  ...                                        252
# 211359              3.0  ...                                         57
# 211518              3.0  ...                                         77
# 211999              1.0  ...                                         17
# 212208              1.0  ...                                        122
#
#         num_foreclosure_per_1000_pin_past_5_years  nearest_cta_route_name  \
# 85                                          25.86                Red Line
# 88                                          38.96                Red Line
# 101                                        103.37              Green Line
# 104                                         32.29                Red Line
# 165                                         18.76                Red Line
# ...                                           ...                     ...
# 211255                                      70.27              Green Line
# 211359                                      19.31               Blue Line
# 211518                                      21.83               Blue Line
# 211999                                       5.53               Blue Line
# 212208                                      57.04              Green Line
#
#         nearest_cta_stop_dist_ft  lake_michigan_dist_ft  \
# 85                  11968.230035           11828.693908
# 88                  30628.719167           21334.582001
# 101                 12439.735556            3295.575031
# 104                 15191.034305           12175.922724
# 165                 34449.573940           23712.695668
# ...                          ...                    ...
# 211255               6570.610024           26181.506779
# 211359               1227.619437           19162.310981
# 211518               1822.114000           15573.537881
# 211999               3721.886645           18537.459764
# 212208               1452.483216           40846.716287
#
#         nearest_metra_stop_dist_ft  nearest_water_dist_ft  \
# 85                     5331.604154           10291.059868
# 88                    19260.991468            3874.155277
# 101                    2343.226246            3295.575031
# 104                    7527.763165            5530.625227
# 165                   21598.269739            2187.124433
# ...                            ...                    ...
# 211255                 6874.136989            4775.103009
# 211359                 6689.081018            4482.496424
# 211518                 5321.266154            3896.896968
# 211999                 6967.030306             902.672069
# 212208                 7591.253328            5636.182589
#
#         nearest_neighbor_1_dist_ft  nearest_neighbor_2_dist_ft  \
# 85                       30.670624                   60.659963
# 88                       39.975687                   39.993200
# 101                      39.042397                   47.495242
# 104                      39.767487                   41.087447
# 165                      25.024367                   25.025674
# ...                            ...                         ...
# 211255                   25.105343                   25.114614
# 211359                   25.012356                   25.013238
# 211518                   24.995481                   25.021251
# 211999                   24.986993                   25.297583
# 212208                   38.096185                   39.851326
#
#         nearest_neighbor_3_dist_ft
# 85                       90.640905
# 88                       79.968141
# 101                      84.988992
# 104                      79.564795
# 165                      50.059607
# ...                            ...
# 211255                   50.220270
# 211359                   49.998406
# 211518                   43.774661
# 211999                   49.994583
# 212208                   77.954605
#
# [3214 rows x 50 columns]

# %%
df_analysis['Estimated Total'] = df_analysis['Estimate (Land)'] + df_analysis['Estimate (Building)']
df_analysis['Estimated Total']
# Out:
# 85        114210
# 88        129220
# 101       208080
# 104        85090
# 165       116550
#            ...
# 211255    123750
# 211359    487850
# 211518    599150
# 211999     79680
# 212208    188180
# Name: Estimated Total, Length: 3214, dtype: int64

# %%
# Drop more variables
df_analysis = df_analysis.drop(columns=['Apartments'])

# %%
# List of all potential string variables for getting dummies
# ['Property Class', 'Neighborhood Code', 'Town Code', 'Type of Residence', 'Basement Finish', 
# 'Central Heating', 'Other Heating', 'Attic Type', 'Garage 1 Size', 'Garage 1 Attachment', 'Garage 1 Area', 
# 'Porch', 'Use', 'property_zip', 'ward_num', 'school_elementary_district_name', 'school_secondary_district_name', 'nearest_cta_route_name']

# %%
cat_dummies = pd.get_dummies(df_analysis, columns=['Property Class', 'Neighborhood Code', 'Town Code', 'Type of Residence', 'Basement Finish', 
'Central Heating', 'Other Heating', 'Attic Type', 'Garage 1 Size', 'Garage 1 Attachment', 'Garage 1 Area', 
'Porch', 'Use', 'property_zip', 'ward_num', 'school_elementary_district_name', 'school_secondary_district_name', 'nearest_cta_route_name'], drop_first=True)
cat_dummies.head()
# Out:
#      Land Square Feet  Rooms  Bedrooms  Basement  Central Air  Fireplaces  \
# 85               3643      5         3         1        False           0
# 88               5000      4         2         1         True           0
# 101              5625      8         4         1        False           0
# 104              5103      4         2         1        False           0
# 165              3225      6         3         1        False           0
#
#      Half Baths  Building Square Feet  Estimate (Land)  Estimate (Building)  \
# 85            0                   982            29140                85070
# 88            0                  1044            30000                99220
# 101           1                  1998            70310               137770
# 104           0                   797            25510                59580
# 165           1                  1260            19350                97200
#
#      ...  school_secondary_district_name_CPS SECONDARY - VOISE HS  \
# 85   ...                                              False
# 88   ...                                              False
# 101  ...                                              False
# 104  ...                                              False
# 165  ...                                              False
#
#      school_secondary_district_name_CPS SECONDARY - WASHINGTON HS  \
# 85                                               False
# 88                                                True
# 101                                              False
# 104                                              False
# 165                                               True
#
#      school_secondary_district_name_CPS SECONDARY - WELLS HS  \
# 85                                               False
# 88                                               False
# 101                                              False
# 104                                              False
# 165                                              False
#
#      nearest_cta_route_name_Brown Line  nearest_cta_route_name_Green Line  \
# 85                               False                              False
# 88                               False                              False
# 101                              False                               True
# 104                              False                              False
# 165                              False                              False
#
#      nearest_cta_route_name_Orange Line  nearest_cta_route_name_Pink Line  \
# 85                                False                             False
# 88                                False                             False
# 101                               False                             False
# 104                               False                             False
# 165                               False                             False
#
#      nearest_cta_route_name_Purple Line  nearest_cta_route_name_Red Line  \
# 85                                False                             True
# 88                                False                             True
# 101                               False                            False
# 104                               False                             True
# 165                               False                             True
#
#      nearest_cta_route_name_Yellow Line
# 85                                False
# 88                                False
# 101                               False
# 104                               False
# 165                               False
#
# [5 rows x 635 columns]

# %% [markdown]
# ### Step 2: Create the labels set (`y`)  from the “loan_status” column, and then create the features (`X`) DataFrame from the remaining columns.

# %%
# Separate the data into labels and features

# Separate the y variable, the labels
# YOUR CODE HERE!]
y = cat_dummies["Sale Price"]

# Separate the X variable, the features
X = cat_dummies.drop(columns=["Sale Price"])

# %%
# Review the y variable Series
y.head()
# Out:
# 85     172000
# 88     120000
# 101    329000
# 104    107200
# 165    115000
# Name: Sale Price, dtype: int64

# %%
# Review the X variable DataFrame
X.head()
# Out:
#      Land Square Feet  Rooms  Bedrooms  Basement  Central Air  Fireplaces  \
# 85               3643      5         3         1        False           0
# 88               5000      4         2         1         True           0
# 101              5625      8         4         1        False           0
# 104              5103      4         2         1        False           0
# 165              3225      6         3         1        False           0
#
#      Half Baths  Building Square Feet  Estimate (Land)  Estimate (Building)  \
# 85            0                   982            29140                85070
# 88            0                  1044            30000                99220
# 101           1                  1998            70310               137770
# 104           0                   797            25510                59580
# 165           1                  1260            19350                97200
#
#      ...  school_secondary_district_name_CPS SECONDARY - VOISE HS  \
# 85   ...                                              False
# 88   ...                                              False
# 101  ...                                              False
# 104  ...                                              False
# 165  ...                                              False
#
#      school_secondary_district_name_CPS SECONDARY - WASHINGTON HS  \
# 85                                               False
# 88                                                True
# 101                                              False
# 104                                              False
# 165                                               True
#
#      school_secondary_district_name_CPS SECONDARY - WELLS HS  \
# 85                                               False
# 88                                               False
# 101                                              False
# 104                                              False
# 165                                              False
#
#      nearest_cta_route_name_Brown Line  nearest_cta_route_name_Green Line  \
# 85                               False                              False
# 88                               False                              False
# 101                              False                               True
# 104                              False                              False
# 165                              False                              False
#
#      nearest_cta_route_name_Orange Line  nearest_cta_route_name_Pink Line  \
# 85                                False                             False
# 88                                False                             False
# 101                               False                             False
# 104                               False                             False
# 165                               False                             False
#
#      nearest_cta_route_name_Purple Line  nearest_cta_route_name_Red Line  \
# 85                                False                             True
# 88                                False                             True
# 101                               False                            False
# 104                               False                             True
# 165                               False                             True
#
#      nearest_cta_route_name_Yellow Line
# 85                                False
# 88                                False
# 101                               False
# 104                               False
# 165                               False
#
# [5 rows x 634 columns]

# %% [markdown]
# ### Step 3: Split the data into training and testing datasets by using `train_test_split`.

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
# Assign a random_state of 1 to the function
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1)
X_train.shape
# Out:
# (2410, 634)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler

# %%
# Creating StandardScaler instance
scaler = StandardScaler()

# %%
# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a random forest classifier
rf_model = RandomForestRegressor(n_estimators=500, random_state=78)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
predictions = rf_model.predict(X_test_scaled)

# %% [markdown]
# ---

# %% [markdown]
# ## Create a Logistic Regression Model with the Original Data

# %% [markdown]
# ###  Step 1: Fit a logistic regression model by using the training data (`X_train` and `y_train`).

# %% [markdown]
# ### Step 2: Save the predictions on the testing data labels by using the testing feature data (`X_test`) and the fitted model.

# %%
# Make a prediction using the testing data
results = pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
results.head(10)
# Out:
#    Prediction  Actual
# 0  282449.996  272400
# 1  272765.874  375900
# 2  173076.906  105000
# 3  353301.720  540000
# 4  158834.474  165000
# 5  282161.896  250000
# 6  296925.456  182500
# 7  337399.766  250000
# 8  177397.116  171000
# 9  323175.426  213000

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predictions))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, predictions))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# Mean Absolute Error: 60415.25187562189
# Mean Squared Error: 7113266660.44435
# Root Mean Squared Error: 84340.18413807472
